# %% [markdown]
# ## Working on automobile data_sets

# %%
import pandas as pd

# %%
df=pd.read_csv('Automobile.csv')

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.drop('index',axis=1,inplace=True)

# %%
df.head()
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3         audi        sedan        99.8   176.6         ohc             four
# 4         audi        sedan        99.4   176.6         ohc             five
#
#    horsepower  average-mileage    price
# 0         111               21  13495.0
# 1         111               21  16500.0
# 2         154               19  16500.0
# 3         102               24  13950.0
# 4         115               18  17450.0

# %%
df.price.max()
# Out:
# 45400.0

# %%
df['price'].max()
# Out:
# 45400.0

# %%
df.loc[df['price']==df['price'].max(),'company':'length']
# Out:
#           company body-style  wheel-base  length
# 35  mercedes-benz    hardtop       112.0   199.2

# %%
df[df.price==df['price'].max()][['company','length']]
# Out:
#           company  length
# 35  mercedes-benz   199.2

# %% [markdown]
# ### Print all the toyota cars details

# %%
grp=df.groupby('company')

# %%
grp.get_group('toyota')
# Out:
#    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48  toyota  hatchback        95.7   158.7         ohc             four
# 49  toyota  hatchback        95.7   158.7         ohc             four
# 50  toyota  hatchback        95.7   158.7         ohc             four
# 51  toyota      wagon        95.7   169.7         ohc             four
# 52  toyota      wagon        95.7   169.7         ohc             four
# 53  toyota      wagon        95.7   169.7         ohc             four
# 54  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %% [markdown]
# ### count total counts of cars

# %%
grp[['company']].count()
# Out:
#                company
# company
# alfa-romero          3
# audi                 4
# bmw                  6
# chevrolet            3
# dodge                2
# honda                3
# isuzu                3
# jaguar               3
# mazda                5
# mercedes-benz        4
# mitsubishi           4
# nissan               5
# porsche              3
# toyota               7
# volkswagen           4
# volvo                2

# %%
print('numbers of companies:',grp['company'].count().count())
# Out:
# numbers of companies: 16

# %%
grp.size()
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            3
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          3
# toyota           7
# volkswagen       4
# volvo            2
# dtype: int64

# %% [markdown]
# ### Find each companies highest price cars

# %%
grp['price'].max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %% [markdown]
# ### Find the average mileage of each car making company

# %%
grp['price'].mean()
# Out:
# company
# alfa-romero      15498.333333
# audi             16392.500000
# bmw              27213.333333
# chevrolet         6007.000000
# dodge             6303.000000
# honda            10195.000000
# isuzu             6785.000000
# jaguar           34600.000000
# mazda             9654.800000
# mercedes-benz    35040.000000
# mitsubishi        6689.000000
# nissan            8289.000000
# porsche          35528.000000
# toyota            8216.857143
# volkswagen        8435.000000
# volvo            13177.500000
# Name: price, dtype: float64

# %% [markdown]
# ### Find the average mileage of each car making company

# %%
grp['average-mileage'].mean()
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %% [markdown]
# ### Sort all cars by Price column

# %%
df.sort_values(by='price')
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# 13      chevrolet  hatchback        88.4   141.1           l            three
# 27          mazda  hatchback        93.1   159.1         ohc             four
# 48         toyota  hatchback        95.7   158.7         ohc             four
# 36     mitsubishi  hatchback        93.7   157.3         ohc             four
# 28          mazda  hatchback        93.1   159.1         ohc             four
# ..            ...        ...         ...     ...         ...              ...
# 11            bmw      sedan       103.5   193.8         ohc              six
# 35  mercedes-benz    hardtop       112.0   199.2        ohcv            eight
# 22          isuzu      sedan        94.5   155.9         ohc             four
# 23          isuzu      sedan        94.5   155.9         ohc             four
# 47        porsche  hatchback        98.4   175.7       dohcv            eight
#
# ...

# %% [markdown]
# ### apply()
# Pandas.apply allow the users to pass a function and apply it on every single value of the Pandas series.

# %%
df.head()
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3         audi        sedan        99.8   176.6         ohc             four
# 4         audi        sedan        99.4   176.6         ohc             five
#
#    horsepower  average-mileage    price
# 0         111               21  13495.0
# 1         111               21  16500.0
# 2         154               19  16500.0
# 3         102               24  13950.0
# 4         115               18  17450.0

# %%
def rate(x):
    if x>36000:
        return 'expensive'
    else:
        return 'Non-Expensive'

# %%
df['new_col']=df['price'].apply(rate)

# %%
df.loc[5:15,['price','company','new_col']]
# Out:
#       price    company        new_col
# 5   15250.0       audi  Non-Expensive
# 6   18920.0       audi  Non-Expensive
# 7   16430.0        bmw  Non-Expensive
# 8   16925.0        bmw  Non-Expensive
# 9   20970.0        bmw  Non-Expensive
# 10  30760.0        bmw  Non-Expensive
# 11  41315.0        bmw      expensive
# 12  36880.0        bmw      expensive
# 13   5151.0  chevrolet  Non-Expensive
# 14   6295.0  chevrolet  Non-Expensive
# 15   6575.0  chevrolet  Non-Expensive

# %% [markdown]
# ### convert name of companies to uppercase and store in a new col

# %%
def upper(x):
    return x.upper()

# %%
df['new']=df['company'].apply(upper)

# %%
df[['company','new']].head()
# Out:
#        company          new
# 0  alfa-romero  ALFA-ROMERO
# 1  alfa-romero  ALFA-ROMERO
# 2  alfa-romero  ALFA-ROMERO
# 3         audi         AUDI
# 4         audi         AUDI

# %% [markdown]
# ### Anonymous function:

# %%
x=lambda x,y:x+y

# %%
x(1,2)
# Out:
# 3

# %%
df['gprice']=df['price'].apply(lambda x:x>17000)

# %%
df[['price','gprice','company']]
# Out:
#       price  gprice      company
# 0   13495.0   False  alfa-romero
# 1   16500.0   False  alfa-romero
# 2   16500.0   False  alfa-romero
# 3   13950.0   False         audi
# 4   17450.0    True         audi
# ..      ...     ...          ...
# 56   7975.0   False   volkswagen
# 57   7995.0   False   volkswagen
# 58   9995.0   False   volkswagen
# 59  12940.0   False        volvo
# 60  13415.0   False        volvo
#
# [61 rows x 3 columns]

# %%
df.head(3)
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
#
#    horsepower  average-mileage    price        new_col          new  gprice
# 0         111               21  13495.0  Non-Expensive  ALFA-ROMERO   False
# 1         111               21  16500.0  Non-Expensive  ALFA-ROMERO   False
# 2         154               19  16500.0  Non-Expensive  ALFA-ROMERO   False

# %%
df['body-style']=df['body-style'].apply(lambda x:x.capitalize())

# %%
df.loc[:5,'company':'length']
# Out:
#        company   body-style  wheel-base  length
# 0  alfa-romero  Convertible        88.6   168.8
# 1  alfa-romero  Convertible        88.6   168.8
# 2  alfa-romero    Hatchback        94.5   171.2
# 3         audi        Sedan        99.8   176.6
# 4         audi        Sedan        99.4   176.6
# 5         audi        Sedan        99.8   177.3

# %% [markdown]
# ### Matplotlib for data visualization

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)

# %%
x=[7,1,9]
y=[3,5,2]
plt.plot(x,y,color='red')
plt.title('info')
plt.xlabel('x axis')
plt.ylabel('y axis')
print(plt.plot(x,y))

# %%
import numpy as np
company=['GOOGL', 'AMZN', 'MSFT', 'FB']
revenue = [90, 136, 89, 27]
profit=[40, 2, 34, 12]
xpos=np.arange(len(company)) # xpos = [0,1,2,3]
plt.xticks(xpos, company) #yticks
plt.ylabel('revenue')
plt.title('US Tech Stocks')
plt.bar(xpos-0.2 ,revenue, label='Revenue', width=0.3)
plt.bar(xpos+0.2, profit, label='Profit',width=0.3)
plt.legend()
plt.show()

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=[80,100,120,150])
plt.xlabel('blood sugar')
plt.ylabel('count of patients')
plt.show()

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar)
plt.xlabel('blood sugar')
plt.ylabel('count of patients')
plt.show()

# %%
import pandas as pd

# %%
data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
grp=data.groupby('Age')

# %%
grp.get_group(18)
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446

# %%
data.loc[data['Age']>25,:]
# Out:
#     Age  All_Devs  Python  JavaScript
# 8    26     42000   48876       43515
# 9    27     46752   53850       46823
# 10   28     49320   57287       49293
# 11   29     53200   63016       53437
# 12   30     56000   65998       56373
# 13   31     62316   70003       62375
# 14   32     64928   70000       66674
# 15   33     67317   71496       68745
# 16   34     68748   75370       68746
# 17   35     73752   83640       74583
# 18   36     77232   84666       79000
# 19   37     78000   84392       78508
# 20   38     78508   78254       79996
# 21   39     79536   85000       80403
# 22   40     82488   87038       83820
# 23   41     88935   91991       88833
# 24   42     90000  100000       91660
# 25   43     90056   94796       87892
# 26   44     95000   97962       96243
# 27   45     90000   93302       90000
# 28   46     91633   99240       99313
# 29   47     91660  102736       91660
# 30   48     98150  112285      102264
# 31   49     98964  100771      100000
# ...

# %%
data[data.Age>52]
# Out:
#     Age  All_Devs  Python  JavaScript
# 35   53    108923  112542      108000
# 36   54    105000  122870      105000
# 37   55    103117  120000      104000

# %%
data.loc[data['Age']>40,'Age':'Python']
# Out:
#     Age  All_Devs  Python
# 23   41     88935   91991
# 24   42     90000  100000
# 25   43     90056   94796
# 26   44     95000   97962
# 27   45     90000   93302
# 28   46     91633   99240
# 29   47     91660  102736
# 30   48     98150  112285
# 31   49     98964  100771
# 32   50    100000  104708
# 33   51     98988  108423
# 34   52    100000  101407
# 35   53    108923  112542
# 36   54    105000  122870
# 37   55    103117  120000

# %%
data[data.Age==data['Age'].max()]
# Out:
#     Age  All_Devs  Python  JavaScript
# 37   55    103117  120000      104000

# %%
ages = data['Age']
dev_other = data['All_Devs']
dev_py = data['Python']
dev_js = data['JavaScript']

# %%
plt.hist(ages, bins=[10,20,30,40,50], rwidth=0.95)
plt.show()

# %%
# plt.style.use('fivethirtyeight')
plt.plot(ages, dev_other, label='Other developer')
plt.plot(ages, dev_py, label='Python developer')
plt.plot(ages, dev_js, label='Javascript developer', linestyle='--')
plt.title('Salaries info')
plt.xlabel('Age')
plt.ylabel('Salaries')
plt.legend()
plt.show()

# %%
exp_vals =[1600, 600, 300, 410, 250]
exp_labels=['Home rent', 'Food', 'Phone/Internet Bill', 'Car', 'Other utilities']
plt.pie(exp_vals, labels = exp_labels,autopct ='%0.2f%%', explode=[0,0,0,0.0,0.1])
plt.show()
